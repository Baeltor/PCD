# %% [markdown]
# <a href="https://colab.research.google.com/github/Baeltor/PCD/blob/main/Exploraci%C3%B3n_dataset_gu%C3%ADa_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Baeltor/PCD/main/Ejercicios/10.000_Empresas_mas_Grandes_del_Pa_s_20240822.csv')

# %%
df.head()
# Out:
#          NIT                   RAZÓN SOCIAL       SUPERVISOR  \
# 0  899999068                  ECOPETROL S.A  SUPERFINANCIERA
# 1  900112515   REFINERIA DE CARTAGENA S.A.S  SUPERSOCIEDADES
# 2  830095213       ORGANIZACIÓN TERPEL S.A.  SUPERFINANCIERA
# 3  860069804  CARBONES DEL CERREJON LIMITED  SUPERSOCIEDADES
# 4  800021308                   DRUMMOND LTD  SUPERSOCIEDADES
#
#                   REGIÓN DEPARTAMENTO DOMICILIO         CIUDAD DOMICILIO  \
# 0  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA D.C.-BOGOTA D.C.
# 1        Costa Atlántica                BOLIVAR        CARTAGENA-BOLIVAR
# 2  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA D.C.-BOGOTA D.C.
# 3  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA D.C.-BOGOTA D.C.
# 4  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA D.C.-BOGOTA D.C.
#
#    CIIU  MACROSECTOR INGRESOS OPERACIONALES GANANCIA (PÉRDIDA) TOTAL ACTIVOS  \
# 0   610       MINERO                $144.82             $33.41       $216.85
# ...

# %%
len(df['NIT'].unique())
# Out:
# 11441

# %%
df.columns
# Out:
# Index(['NIT', 'RAZÓN SOCIAL', 'SUPERVISOR', 'REGIÓN', 'DEPARTAMENTO DOMICILIO',
#        'CIUDAD DOMICILIO', 'CIIU', 'MACROSECTOR', 'INGRESOS OPERACIONALES',
#        'GANANCIA (PÉRDIDA)', 'TOTAL ACTIVOS', 'TOTAL PASIVOS',
#        'TOTAL PATRIMONIO', 'Año de Corte'],
#       dtype='object')

# %%
len(df['Año de Corte'].unique())
# Out:
# 2

# %%
df['Año de Corte'].value_counts()
# Out:
# Año de Corte
# 2022    10000
# 2021    10000
# Name: count, dtype: int64

# %%
len(df[df['Año de Corte']==2022]['NIT'].unique())
# Out:
# 10000

# %%
len(df[df['Año de Corte']==2021]['NIT'].unique())
# Out:
# 10000

# %%
empresas_con_altos_ingresos_consecutivos = list(set(df[df['Año de Corte']==2022]['NIT'].unique())
& set(df[df['Año de Corte']==2021]['NIT'].unique()))

# %%
df[df['Año de Corte']==2022]['NIT'].unique()
# Out:
# array([899999068, 900112515, 830095213, ..., 800078122, 860036365,
#        900107634])

# %%
df[df['NIT'].isin(empresas_con_altos_ingresos_consecutivos)]
# Out:
#              NIT                                       RAZÓN SOCIAL  \
# 0      899999068                                      ECOPETROL S.A
# 1      900112515                       REFINERIA DE CARTAGENA S.A.S
# 2      830095213                           ORGANIZACIÓN TERPEL S.A.
# 3      860069804                      CARBONES DEL CERREJON LIMITED
# 4      800021308                                       DRUMMOND LTD
# ...          ...                                                ...
# 19980  900451723                               SOGA DE COLOMBIA SAS
# 19983  802005761  GRUPO MAESTRA COMPAÑIA DE MANTENIMIENTOS Y SUM...
# 19985  890406689                                    ER Y CIA S EN C
# 19990  900307175                          INDSUTRIAL CONSULTING SAS
# 19997  901021850                 EDGE NETWORK SERVICES COLOMBIA SAS
#
#             SUPERVISOR                 REGIÓN DEPARTAMENTO DOMICILIO  \
# 0      SUPERFINANCIERA  Bogotá - Cundinamarca            BOGOTA D.C.
# ...

# %% [markdown]
# ## como debe ser el sistema de archivos de los módulos

# %% [markdown]
# | -- folder_funciones/
#
#     | -- __init__.py
#
#     | -- modulo_1.py
#
#     | -- modulo_2.py
#
#     | -- modulo_3.py

# %%
df['MACROSECTOR'].value_counts()
# Out:
# MACROSECTOR
# COMERCIO        6756
# SERVICIOS       6192
# MANUFACTURA     4135
# CONSTRUCCIÓN    1586
# AGROPECUARIO     927
# MINERO           404
# Name: count, dtype: int64
